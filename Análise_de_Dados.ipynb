# %% [markdown]
# <a href="https://colab.research.google.com/github/NathaliaRJ03/CalculadoraSimples/blob/main/An%C3%A1lise_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as  px

# %%
df_principal = pd.read_excel("/content/DADOS.EXCEL.xlsx", sheet_name= "Principal")
df_principal.head (12)
# Out:
#     SIMBOLO DA AÇÃO  NOME DA EMPRESA  PREÇO ATIVO  VARIAÇÃO %  \
# 0             BBDC4         Bradesco          150         1.5
# 1             ITUB4             Itau         2700        -8.0
# 2            SANB11        Santander          300         2.2
# 3             BBAS3  Banco do Brasil          650         3.0
# 4            NUBR33           Nubank          700         6.0
# 5            INBR32            Inter          400         4.5
# 6               PIO           PicPay          200         3.2
# 7            MELI34     Mercado Pago         1400         4.0
# 8             DIO37            Digio          220         3.3
# 9             NE1TX             Next          620         2.6
# 10               B3          C6 Bank          340         1.1
#
#     QUANTIDADE DE AÇÃO
# 0                   10
# 1                    5
# 2                    8
# 3                    3
# 4                    8
# 5                    6
# 6                    4
# 7                    7
# ...

# %% [markdown]
# Aula 2 - Importação

# %%
df_renda = pd.read_excel("/content/DADOS.EXCEL.xlsx", sheet_name= "Renda")
df_renda
# Out:
#     Parcerias  Propostas  Investimento  AÇÕES ATUAIS
# 0           4          1         40000            14
# 1           7          4         34000             9
# 2           3          4         45554             3
# 3           6          3         23000            12
# 4           2          8         56000            10
# 5           6          1         25000            18
# 6           9          5         76000            23
# 7           5          9         33000             2
# 8           4          4         89000             6
# 9           2          8         56000            11
# 10          5          1         43000             9

# %%
df_funcionarios = pd.read_excel("/content/DADOS.EXCEL.xlsx", sheet_name= "Funcionarios")
df_funcionarios
# Out:
#                  SETOR  Funcionarios (SP)  Funcionarios (RS)  \
# 0              Gerente                180                200
# 1             Analista                120                160
# 2                Caixa                567                600
# 3             Aprendiz                 45                 70
# 4           Estagiario                 80                120
# 5              Desenv.                250                346
# 6        Especialistas                145                267
# 7     Agente comercial                230                346
# 8              Suporte                 30                 56
# 9      Segundo Gerente                  8                 14
# 10  Assistentes Gerais                 95                 40
#
#     Funcionarios (RJ)
# 0                 230
# 1                 150
# 2                 600
# 3                  50
# 4                 100
# 5                 320
# 6                 240
# 7                 310
# ...

# %%
df_gastos = pd.read_excel("/content/DADOS.EXCEL.xlsx", sheet_name= "Gastos")
df_gastos
# Out:
#     Despesas  Perdas  Equipamentos  Perdas nos Investimentos
# 0     500000    0.03        900000                        16
# 1     764000    0.12        450000                         6
# 2     860000    0.06        340000                         8
# 3     755000    0.15        670000                         5
# 4     945000    0.11        920000                         3
# 5     366000    0.02        820000                         8
# 6     690000    0.06        560000                        16
# 7     880000    0.04        830000                         3
# 8     450000    0.14        940000                         8
# 9     760000    0.11        380000                        11
# 10    960000    0.04        430000                        14

# %%
df_principal = df_principal.rename (columns= {'NOME DA EMPRESA': 'NOME',	'PREÇO ATIVO': 'PREÇO ATUAl'}).copy()
df_principal
# Out:
#     SIMBOLO DA AÇÃO             NOME  PREÇO ATUAl  VARIAÇÃO %  \
# 0             BBDC4         Bradesco          150         1.5
# 1             ITUB4             Itau         2700        -8.0
# 2            SANB11        Santander          300         2.2
# 3             BBAS3  Banco do Brasil          650         3.0
# 4            NUBR33           Nubank          700         6.0
# 5            INBR32            Inter          400         4.5
# 6               PIO           PicPay          200         3.2
# 7            MELI34     Mercado Pago         1400         4.0
# 8             DIO37            Digio          220         3.3
# 9             NE1TX             Next          620         2.6
# 10               B3          C6 Bank          340         1.1
#
#     QUANTIDADE DE AÇÃO
# 0                   10
# 1                    5
# 2                    8
# 3                    3
# 4                    8
# 5                    6
# 6                    4
# 7                    7
# ...

# %%
df_principal = df_principal.drop (columns=['NOME'])
df_principal
# Out:
#     SIMBOLO DA AÇÃO  PREÇO ATUAl  VARIAÇÃO %  QUANTIDADE DE AÇÃO
# 0             BBDC4          150         1.5                  10
# 1             ITUB4         2700        -8.0                   5
# 2            SANB11          300         2.2                   8
# 3             BBAS3          650         3.0                   3
# 4            NUBR33          700         6.0                   8
# 5            INBR32          400         4.5                   6
# 6               PIO          200         3.2                   4
# 7            MELI34         1400         4.0                   7
# 8             DIO37          220         3.3                   1
# 9             NE1TX          620         2.6                   4
# 10               B3          340         1.1                   2

# %%
df_principal ["PRECO_SOMA_ACAO"] = (df_principal["PREÇO ATUAl"]) + (df_principal ["QUANTIDADE DE AÇÃO"])
df_principal
# Out:
#     SIMBOLO DA AÇÃO  PREÇO ATUAl  VARIAÇÃO %  QUANTIDADE DE AÇÃO  \
# 0             BBDC4          150         1.5                  10
# 1             ITUB4         2700        -8.0                   5
# 2            SANB11          300         2.2                   8
# 3             BBAS3          650         3.0                   3
# 4            NUBR33          700         6.0                   8
# 5            INBR32          400         4.5                   6
# 6               PIO          200         3.2                   4
# 7            MELI34         1400         4.0                   7
# 8             DIO37          220         3.3                   1
# 9             NE1TX          620         2.6                   4
# 10               B3          340         1.1                   2
#
#     PRECO_SOMA_ACAO
# 0               160
# 1              2705
# 2               308
# 3               653
# 4               708
# 5               406
# 6               204
# ...

# %%
df_principal
# Out:
#     SIMBOLO DA AÇÃO  PREÇO ATUAl  VARIAÇÃO %  QUANTIDADE DE AÇÃO  \
# 0             BBDC4          150         1.5                  10
# 1             ITUB4         2700        -8.0                   5
# 2            SANB11          300         2.2                   8
# 3             BBAS3          650         3.0                   3
# 4            NUBR33          700         6.0                   8
# 5            INBR32          400         4.5                   6
# 6               PIO          200         3.2                   4
# 7            MELI34         1400         4.0                   7
# 8             DIO37          220         3.3                   1
# 9             NE1TX          620         2.6                   4
# 10               B3          340         1.1                   2
#
#     PRECO_SOMA_ACAO
# 0               160
# 1              2705
# 2               308
# 3               653
# 4               708
# 5               406
# 6               204
# ...

# %%
df_AnaliseFinal_Gastos = df_gastos.groupby('Despesas')['Equipamentos'].sum().reset_index()
df_AnaliseFinal_Gastos
# Out:
#     Despesas  Equipamentos
# 0     366000        820000
# 1     450000        940000
# 2     500000        900000
# 3     690000        560000
# 4     755000        670000
# 5     760000        380000
# 6     764000        450000
# 7     860000        340000
# 8     880000        830000
# 9     945000        920000
# 10    960000        430000

# %%
fig = px.bar(df_funcionarios, x = "SETOR", y ="Funcionarios (RJ)", text= "Funcionarios (RJ)", title="TOTAL_DE_FUNCIONARIOS_RJ")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df_funcionarios, x = "SETOR", y ="Funcionarios (SP)", text= "Funcionarios (SP)", title="TOTAL_DE_FUNCIONARIOS_SP")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
